# %%
print("testing conda venv\nleveraging different environments")
# Out:
# testing conda venv
# leveraging different environments

# %%
import matplotlib 
import lsdtt_xtensor_python
import lsdtopytools
import lsdviztools
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/sciclone/home/ntlewis/research/.conda/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/sciclone/home/ntlewis/research/.conda/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/sciclone/home/ntlewis/research/.conda/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %%
# !conda list
# Out:
# # packages in environment at /sciclone/home/ntlewis/research/.conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# affine                    2.3.0              pyhd3eb1b0_0
# alsa-lib                  1.2.13               hb9d3cd8_0    conda-forge
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# attr                      2.5.1                h166bdaf_1    conda-forge
# attrs                     24.3.0           py39h06a4308_0
# blas                      1.0                    openblas
# blosc                     1.21.6               hef167b5_0    conda-forge
# bottleneck                1.4.2            py39ha9d4c09_0
# branca                    0.6.0            py39h06a4308_0
# brotli-python             1.0.9            py39h6a678d5_9
# ...
